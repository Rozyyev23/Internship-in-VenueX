# %%
import requests
from bs4 import BeautifulSoup

# %%
import urllib
from urllib import parse

# %%
base_url = 'https://kinoteatr.ru'

# %%
a = requests.get(f'{base_url}/raspisanie-kinoteatrov')

# %%
r = requests.get(f'{base_url}/raspisanie-kinoteatrov//?day=tomorrow')

# %%
soap = BeautifulSoup(r.text, 'lxml')

# %%
cinemastt = []

# %%
s = BeautifulSoup(a.text, 'lxml')

# %%
cinemas = []

# %%
for i in s.findAll('div', class_='col-md-12 cinema_card'):
    name = i.find('h3').text.strip()
    href = i.find('a')['href'].strip()
    address = i.findAll('span', class_= 'sub_title')[0].text.strip()
    cinemas.append({
        'name': name,
        'href': href,
        'address': address,
    })
    print(name, href, address, sep='\n', end='\n---------------------\n')
# Out:
# Синема Парк Мега Белая Дача
# https://kinoteatr.ru/raspisanie-kinoteatrov/belaya-dacha/
# Московская обл., Люберецкий р-н, г. Котельники, 1-й Покровский проезд, д. 1, (14-й км МКАД), «МЕГА Белая дача», 1-й этаж
# ---------------------
# Синема Парк Бутово Молл
# https://kinoteatr.ru/raspisanie-kinoteatrov/butovo-mall/
# Москва, пос. Воскресенское, Чечерский пр., 51, ТРЦ «Бутово-молл»
# ---------------------
# Кронверк Синема Вэйпарк
# https://kinoteatr.ru/raspisanie-kinoteatrov/waypark/
# Москва, 71-й км МКАД, ТРЦ «Вэйпарк»
# ---------------------
# Синема Парк Глобал Сити на Южной
# https://kinoteatr.ru/raspisanie-kinoteatrov/global-city/
# Москва, ул. Днепропетровская, д.2, ТРК Глобал Сити, 3-й этаж
# ---------------------
# Формула Кино Европа
# https://kinoteatr.ru/raspisanie-kinoteatrov/evropa/
# Москва, пл. Киевского Вокзала, 2, ТРЦ «Европейский»
# ---------------------
# Синема Парк Зеленопарк
# https://kinoteatr.ru/raspisanie-kinoteatrov/zelenopark/
# Зеленоград, Ленинградское шоссе, 18-й км, ТЦ «Zеленопарк»
# ---------------------
# Синема Парк на Калужской
# https://kinoteatr.ru/raspisanie-kinoteatrov/kaluzhskij/
# Москва, ул. Профсоюзная, 61a, ТЦ Калужский, 3-й этаж
# ---------------------
# Формула Кино на Кутузовском
# https://kinoteatr.ru/raspisanie-kinoteatrov/kutuzovskiy/
# Москва, Кутузовский просп., 57, ТРЦ «Океания»
# ---------------------
# Формула Кино Ладога
# https://kinoteatr.ru/raspisanie-kinoteatrov/ladoga/
# Москва, Широкая, 12
# ---------------------
# Формула Кино Лефортово
# https://kinoteatr.ru/raspisanie-kinoteatrov/lefortovo/
# Москва, ш. Энтузиастов, 12, корп. 2, ТК «Город Лефортово»
# ---------------------
# Синема Парк Метрополис на Войковской
# https://kinoteatr.ru/raspisanie-kinoteatrov/metropolis/
# Москва, Ленинградское шоссе, 16A, стр 4 ТЦ «Метрополис», 3-й этаж
# ---------------------
# Формула Кино на Мичуринском
# https://kinoteatr.ru/raspisanie-kinoteatrov/michurinsky/
# Москва, Мичуринский просп., Олимпийская деревня, 3, корп. 1, ТРЦ «Фестиваль»
# ---------------------
# Формула Кино на Можайке
# https://kinoteatr.ru/raspisanie-kinoteatrov/mozhayka/
# Москва, 53-й км МКАД, напротив гипермаркета «Ашан Марфино»
# ---------------------
# Кронверк Синема Облака
# https://kinoteatr.ru/raspisanie-kinoteatrov/oblaka/
# Москва, Ореховый б-р, 22а, ТРК «Облака»
# ---------------------
# Формула Кино на Полежаевской
# https://kinoteatr.ru/raspisanie-kinoteatrov/polezhaevskiy/
# Москва, Хорошевское шоссе, д. 27, ТРЦ «Хорошо!»
# ---------------------
# Синема Парк Пятая Авеню на Октябрьском Поле
# https://kinoteatr.ru/raspisanie-kinoteatrov/5avenu/
# Москва, ул. Маршала Бирюзова, 32, ТРЦ «5 Авеню», 3-й этаж
# ---------------------
# Синема Парк Ривьера на Автозаводской
# https://kinoteatr.ru/raspisanie-kinoteatrov/rivera/
# Москва, ул. Автозаводская, 18, ТРЦ «Ривьера», 3-й этаж
# ---------------------
# Кронверк Синема Семеновский
# https://kinoteatr.ru/raspisanie-kinoteatrov/semenovsky/
# Москва, Семеновская пл., 1, ТРЦ «Семеновский»
# ---------------------
# КИНО ОККО Афимолл Сити
# https://kinoteatr.ru/raspisanie-kinoteatrov/city/
# Москва, Пресненская наб., 2, ТЦ «Афимолл-сити»
# ---------------------
# Синема ПАРК Теплый стан
# https://kinoteatr.ru/raspisanie-kinoteatrov/tepliy-stan/
# Москва, п. Сосенское, Калужское шоссе 21км (или 41км МКАД), «МЕГА Тёплый стан», 1-й этаж
# ---------------------
# Синема Парк Филион на Багратионовской
# https://kinoteatr.ru/raspisanie-kinoteatrov/filion/
# Москва, Багратионовский пр., 5, ТРЦ «Филион», 4-й этаж
# ---------------------
# Синема Парк МЕГА Химки
# https://kinoteatr.ru/raspisanie-kinoteatrov/mega-himki/
# Московская обл., г. Химки, мкр-н ИКЕА, корпус 2, «МЕГА Химки», 2-й этаж
# ---------------------
# Формула Кино ЦДМ
# https://kinoteatr.ru/raspisanie-kinoteatrov/cdm/
# Москва, Театральный пр., 5/1, Центральный детский магазин
# ---------------------
# Формула Кино Чертаново
# https://kinoteatr.ru/raspisanie-kinoteatrov/chertanovo/
# Москва, мкр. Северное Чертаново, 1а, стр. 2, ТРЦ «Авентура»
# ---------------------
# Кино Оkkо Щёлковский
# https://kinoteatr.ru/raspisanie-kinoteatrov/shchelkovsky/
# г. Москва, Щёлковское шоссе, 75
# ---------------------

# %%
for ind, cinema in enumerate(cinemas):
    r = requests.get(cinema['href'])
    s = BeautifulSoup(r.text, 'lxml')
    films = s.findAll('div', class_='shedule_movie bordered gtm_movie')
    films_dict = []
    for film in films:
        films_dict.append({
            'name':film['data-gtm-list-item-filmname'],
            'href': film.find('a', class_='gtm-ec-list-item-movie')['href'],
            'format': film['data-gtm-format'],
            'genre': film['data-gtm-list-item-genre'],
            'raiting_sub': film.findAll('i', class_='raiting_sub')[0].text.strip(),
            'raspisanie': film.findAll('span', class_='shedule_session_time'),
            'price': film.findAll('span', class_='shedule_session_price')
        })
    cinemas[ind]['films'] = films_dict

# %%
cinemas
# Out:
# [{'name': 'Синема Парк Мега Белая Дача',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/belaya-dacha/',
#   'address': 'Московская обл., Люберецкий р-н, г. Котельники, 1-й Покровский проезд, д. 1, (14-й км МКАД), «МЕГА Белая дача», 1-й этаж',
#   'films': [{'name': 'Ведьмы',
#     'href': 'https://kinoteatr.ru/film/vedmy-2/?cinema_prio=24',
#     'format': '2d,4dx',
#     'genre': 'приключения,семейный,фэнтези',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      10:40
#
#                          </span>,
#      <span class="shedule_session_time">                      11:55
#
#                          </span>,
#      <span class="shedule_session_time">                      14:10
#
#                          </span>,
#      <span class="shedule_session_time">                      16:25
#
#                          </span>,
#      <span class="shedule_session_time">                      18:40
#
#                          </span>,
#      <span class="shedule_session_time">                      20:55
#
#                          </span>,
#      <span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:25
#
#                          </span>,
#      <span class="shedule_session_time">                      12:45
#
#                          </span>,
#      <span class="shedule_session_time">                      15:05
#
#                          </span>,
#      <span class="shedule_session_time">                      17:25
#
#                          </span>,
#      <span class="shedule_session_time">                      19:45
#
#                          </span>,
#      <span class="shedule_session_time">                      22:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      11:30
#
#                          </span>,
#      <span class="shedule_session_time">                      13:55
#
#                          </span>,
#      <span class="shedule_session_time">                      16:20
#
#                          </span>,
#      <span class="shedule_session_time">                      18:45
#
#                          </span>,
#      <span class="shedule_session_time">                      21:10
#
#                          </span>,
#      <span class="shedule_session_time">                      23:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Довод',
#     'href': 'https://kinoteatr.ru/film/dovod/?cinema_prio=24',
#     'format': '4dx,2d,imax',
#     'genre': 'боевик,триллер,фантастика',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:50
#
#                          </span>,
#      <span class="shedule_session_time">                      13:50
#
#                          </span>,
#      <span class="shedule_session_time">                      16:50
#
#                          </span>,
#      <span class="shedule_session_time">                      19:50
#
#                          </span>,
#      <span class="shedule_session_time">                      22:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Питер Пэн и Алиса в Стране чудес',
#     'href': 'https://kinoteatr.ru/film/piter-pen-i-alisa-v-strane-chudes-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'фэнтези',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:30
#
#                          </span>,
#      <span class="shedule_session_time">                      14:15
#
#                          </span>,
#      <span class="shedule_session_time">                      14:55
#
#                          </span>,
#      <span class="shedule_session_time">                      18:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      11:35
#
#                          </span>,
#      <span class="shedule_session_time">                      13:45
#
#                          </span>,
#      <span class="shedule_session_time">                      16:00
#
#                          </span>,
#      <span class="shedule_session_time">                      20:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      11:50
#
#                          </span>,
#      <span class="shedule_session_time">                      16:15
#
#                          </span>,
#      <span class="shedule_session_time">                      20:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      12:30
#
#                          </span>,
#      <span class="shedule_session_time">                      16:55
#
#                          </span>,
#      <span class="shedule_session_time">                      21:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Союз зверей: Спасение двуногих',
#     'href': 'https://kinoteatr.ru/film/soyuz-zverey-spasenie-dvunogih/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:20
#
#                          </span>,
#      <span class="shedule_session_time">                      14:10
#
#                          </span>,
#      <span class="shedule_session_time">                      16:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                310 р.                                        </span>]},
#    {'name': 'Пункт назначения. Аквапарк',
#     'href': 'https://kinoteatr.ru/film/punkt-naznacheniya-akvapark/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      18:10
#
#                          </span>,
#      <span class="shedule_session_time">                      22:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Грань времени',
#     'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'ужасы,фантастика',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      19:55
#
#                          </span>,
#      <span class="shedule_session_time">                      22:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Страна грёз',
#     'href': 'https://kinoteatr.ru/film/strana-gryoz-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      19:20
#
#                          </span>,
#      <span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Подольские курсанты',
#     'href': 'https://kinoteatr.ru/film/podolskie-kursanty/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'драма,исторический',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      17:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Человек из Подольска',
#     'href': 'https://kinoteatr.ru/film/chelovek-iz-podolska-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'драма,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      20:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Не все дома',
#     'href': 'https://kinoteatr.ru/film/ne-vse-doma-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'комедия',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      12:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Академия монстров',
#     'href': 'https://kinoteatr.ru/film/akademiya-monstrov/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      12:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Вечер шутов или серьёзно с приветом',
#     'href': 'https://kinoteatr.ru/film/vecher-shutov-ili-seryozno-s-privetom-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'комедия,мелодрама',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      14:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                310 р.                                        </span>]},
#    {'name': 'Дедушка нелегкого поведения',
#     'href': 'https://kinoteatr.ru/film/gde-moya-chelyust-chuvak-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'комедия,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      16:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Смертельные иллюзии',
#     'href': 'https://kinoteatr.ru/film/smertelnye-illyuzii-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'триллер,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      15:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Необыкновенная история на Рождество',
#     'href': 'https://kinoteatr.ru/film/neobyknovennaya-istoriya-na-rozhdestvo-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'биография,драма,комедия',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      18:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Линия горизонта',
#     'href': 'https://kinoteatr.ru/film/liniya-gorizonta-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      18:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Криминальные боссы',
#     'href': 'https://kinoteatr.ru/film/kriminalnye-bossy/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'криминальная комедия',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                420 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      20:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Бег',
#     'href': 'https://kinoteatr.ru/film/beg/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      12:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]}]},
#  {'name': 'Синема Парк Бутово Молл',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/butovo-mall/',
#   'address': 'Москва, пос. Воскресенское, Чечерский пр., 51, ТРЦ «Бутово-молл»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:20
#
#                          </span>,
#      <span class="shedule_session_time">                      12:35
#
#                          </span>,
#      <span class="shedule_session_time">                      14:50
#
#                          </span>,
#      <span class="shedule_session_time">                      15:45
#
#                          </span>,
#      <span class="shedule_session_time">                      17:05
#
#                          </span>,
#      <span class="shedule_session_time">                      18:25
#
#                          </span>,
#      <span class="shedule_session_time">                      19:20
#
#                          </span>,
#      <span class="shedule_session_time">                      21:35
#
#                          </span>,
#      <span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:40
#
#                          </span>,
#      <span class="shedule_session_time">                      13:00
#
#                          </span>,
#      <span class="shedule_session_time">                      15:20
#
#                          </span>,
#      <span class="shedule_session_time">                      17:40
#
#                          </span>,
#      <span class="shedule_session_time">                      18:45
#
#                          </span>,
#      <span class="shedule_session_time">                      20:00
#
#                          </span>,
#      <span class="shedule_session_time">                      21:05
#
#                          </span>,
#      <span class="shedule_session_time">                      22:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      11:50
#
#                          </span>,
#      <span class="shedule_session_time">                      14:15
#
#                          </span>,
#      <span class="shedule_session_time">                      16:40
#
#                          </span>,
#      <span class="shedule_session_time">                      19:05
#
#                          </span>,
#      <span class="shedule_session_time">                      21:30
#
#                          </span>,
#      <span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      11:15
#
#                          </span>,
#      <span class="shedule_session_time">                      13:30
#
#                          </span>,
#      <span class="shedule_session_time">                      18:00
#
#                          </span>,
#      <span class="shedule_session_time">                      20:15
#
#                          </span>,
#      <span class="shedule_session_time">                      22:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Питер Пэн и Алиса в Стране чудес',
#     'href': 'https://kinoteatr.ru/film/piter-pen-i-alisa-v-strane-chudes-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'фэнтези',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:55
#
#                          </span>,
#      <span class="shedule_session_time">                      12:55
#
#                          </span>,
#      <span class="shedule_session_time">                      14:55
#
#                          </span>,
#      <span class="shedule_session_time">                      16:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      15:00
#
#                          </span>,
#      <span class="shedule_session_time">                      17:25
#
#                          </span>,
#      <span class="shedule_session_time">                      19:50
#
#                          </span>,
#      <span class="shedule_session_time">                      22:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                220 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'МУЛЬТ в кино. Выпуск №119',
#     'href': 'https://kinoteatr.ru/film/mult-v-kino-vypusk-119-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'анимация',
#     'raiting_sub': '0+',
#     'raspisanie': [<span class="shedule_session_time">                      10:15
#
#                          </span>,
#      <span class="shedule_session_time">                      11:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                170 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                170 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      19:40
#
#                          </span>,
#      <span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Линия горизонта',
#     'href': 'https://kinoteatr.ru/film/liniya-gorizonta-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      19:00
#
#                          </span>,
#      <span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      21:40
#
#                          </span>,
#      <span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Союз зверей: Спасение двуногих',
#     'href': 'https://kinoteatr.ru/film/soyuz-zverey-spasenie-dvunogih/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:35
#
#                          </span>,
#      <span class="shedule_session_time">                      16:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                270 р.                                        </span>]},
#    {'name': 'Грань времени',
#     'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'ужасы,фантастика',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      21:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Повелитель драконов',
#     'href': 'https://kinoteatr.ru/film/povelitel-drakonov-2/?cinema_prio=79',
#     'format': '2d,3d',
#     'genre': '',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      14:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Ведьмы',
#     'href': 'https://kinoteatr.ru/film/vedmy-2/?cinema_prio=79',
#     'format': '2d,4dx',
#     'genre': 'приключения,семейный,фэнтези',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      10:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>]},
#    {'name': 'Пункт назначения. Аквапарк',
#     'href': 'https://kinoteatr.ru/film/punkt-naznacheniya-akvapark/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      20:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Смертельные иллюзии',
#     'href': 'https://kinoteatr.ru/film/smertelnye-illyuzii-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      14:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Человек из Подольска',
#     'href': 'https://kinoteatr.ru/film/chelovek-iz-podolska-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'драма,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      16:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                220 р.                                        </span>]},
#    {'name': 'Вечер шутов или серьёзно с приветом',
#     'href': 'https://kinoteatr.ru/film/vecher-shutov-ili-seryozno-s-privetom-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'комедия,мелодрама',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>]},
#    {'name': 'Академия монстров',
#     'href': 'https://kinoteatr.ru/film/akademiya-monstrov/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      12:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      12:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Подольские курсанты',
#     'href': 'https://kinoteatr.ru/film/podolskie-kursanty/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'драма,исторический',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      14:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Страна грёз',
#     'href': 'https://kinoteatr.ru/film/strana-gryoz-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      12:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                180 р.                                        </span>]},
#    {'name': 'Не все дома',
#     'href': 'https://kinoteatr.ru/film/ne-vse-doma-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'комедия',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      17:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Бег',
#     'href': 'https://kinoteatr.ru/film/beg/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      13:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Кронверк Синема Вэйпарк',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/waypark/',
#   'address': 'Москва, 71-й км МКАД, ТРЦ «Вэйпарк»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:15
#
#                          </span>,
#      <span class="shedule_session_time">                      12:30
#
#                          </span>,
#      <span class="shedule_session_time">                      14:45
#
#                          </span>,
#      <span class="shedule_session_time">                      17:00
#
#                          </span>,
#      <span class="shedule_session_time">                      18:20
#
#                          </span>,
#      <span class="shedule_session_time">                      19:40
#
#                          </span>,
#      <span class="shedule_session_time">                      21:10
#
#                          </span>,
#      <span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                190 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:20
#
#                          </span>,
#      <span class="shedule_session_time">                      12:35
#
#                          </span>,
#      <span class="shedule_session_time">                      14:55
#
#                          </span>,
#      <span class="shedule_session_time">                      17:15
#
# ...
#     'format': '2d,3d',
#     'genre': '',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                150 р.                                        </span>]},
#    {'name': 'Дедушка нелегкого поведения',
#     'href': 'https://kinoteatr.ru/film/gde-moya-chelyust-chuvak-2/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'комедия,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      11:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                150 р.                                        </span>]},
#    {'name': 'Союз зверей: Спасение двуногих',
#     'href': 'https://kinoteatr.ru/film/soyuz-zverey-spasenie-dvunogih/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      12:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                240 р.                                        </span>]},
#    {'name': 'Глубже!',
#     'href': 'https://kinoteatr.ru/film/glubzhe/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                150 р.                                        </span>]}]},
#  {'name': 'Кино Оkkо Щёлковский',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/shchelkovsky/',
#   'address': 'г. Москва, Щёлковское шоссе, 75',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      10:45
#
#                          </span>,
#      <span class="shedule_session_time">                      13:15
#
#                          </span>,
#      <span class="shedule_session_time">                      14:10
#
#                          </span>,
#      <span class="shedule_session_time">                      16:30
#
#                          </span>,
#      <span class="shedule_session_time">                      19:00
#
#                          </span>,
#      <span class="shedule_session_time">                      20:15
#
#                          </span>,
#      <span class="shedule_session_time">                      21:15
#
#                          </span>,
#      <span class="shedule_session_time">                      22:30
#
#                          </span>,
#      <span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      10:55
#
#                          </span>,
#      <span class="shedule_session_time">                      13:05
#
#                          </span>,
#      <span class="shedule_session_time">                      15:40
#
#                          </span>,
#      <span class="shedule_session_time">                      17:40
#
#                          </span>,
#      <span class="shedule_session_time">                      21:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      18:40
#
#                          </span>,
#      <span class="shedule_session_time">                      20:45
#
#                          </span>,
#      <span class="shedule_session_time">                      22:15
#
#                          </span>,
#      <span class="shedule_session_time">                      23:00
#
#                          </span>,
#      <span class="shedule_session_time">                      00:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      11:40
#
#                          </span>,
#      <span class="shedule_session_time">                      15:25
#
#                          </span>,
#      <span class="shedule_session_time">                      18:00
#
#                          </span>,
#      <span class="shedule_session_time">                      20:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'Питер Пэн и Алиса в Стране чудес',
#     'href': 'https://kinoteatr.ru/film/piter-pen-i-alisa-v-strane-chudes-2/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'фэнтези',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:50
#
#                          </span>,
#      <span class="shedule_session_time">                      13:25
#
#                          </span>,
#      <span class="shedule_session_time">                      16:40
#
#                          </span>,
#      <span class="shedule_session_time">                      19:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      16:05
#
#                          </span>,
#      <span class="shedule_session_time">                      20:35
#
#                          </span>,
#      <span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'Ведьмы',
#     'href': 'https://kinoteatr.ru/film/vedmy-2/?cinema_prio=89',
#     'format': '2d,4dx',
#     'genre': 'приключения,семейный,фэнтези',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      12:00
#
#                          </span>,
#      <span class="shedule_session_time">                      17:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      13:55
#
#                          </span>,
#      <span class="shedule_session_time">                      18:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                300 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                400 р.                                        </span>]},
#    {'name': 'Повелитель драконов',
#     'href': 'https://kinoteatr.ru/film/povelitel-drakonov-2/?cinema_prio=89',
#     'format': '2d,3d',
#     'genre': '',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      11:30
#
#                          </span>,
#      <span class="shedule_session_time">                      14:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Академия монстров',
#     'href': 'https://kinoteatr.ru/film/akademiya-monstrov/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      10:10
#
#                          </span>,
#      <span class="shedule_session_time">                      12:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Союз зверей: Спасение двуногих',
#     'href': 'https://kinoteatr.ru/film/soyuz-zverey-spasenie-dvunogih/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'анимация,семейный',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      15:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                300 р.                                        </span>]},
#    {'name': 'МУЛЬТ в кино. Выпуск №119',
#     'href': 'https://kinoteatr.ru/film/mult-v-kino-vypusk-119-2/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'анимация',
#     'raiting_sub': '0+',
#     'raspisanie': [<span class="shedule_session_time">                      10:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                120 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]}]}]

# %%
for i1 in soap.findAll('div', class_='col-md-12 cinema_card'):
    name_t= i1.find('h3').text.strip()
    href_t= i1.find('a')['href'].strip()
    address_t= i1.findAll('span', class_='sub_title')[0].text.strip()
    cinemastt.append({
        'name': name_t,
        'href': href_t,
        'address': address_t
    })
    print(name_t, href_t, address_t, sep='\n', end='\n---------------------\n')
# Out:
# Синема Парк Мега Белая Дача
# https://kinoteatr.ru/raspisanie-kinoteatrov/belaya-dacha/?day=tomorrow
# Московская обл., Люберецкий р-н, г. Котельники, 1-й Покровский проезд, д. 1, (14-й км МКАД), «МЕГА Белая дача», 1-й этаж
# ---------------------
# Синема Парк Бутово Молл
# https://kinoteatr.ru/raspisanie-kinoteatrov/butovo-mall/?day=tomorrow
# Москва, пос. Воскресенское, Чечерский пр., 51, ТРЦ «Бутово-молл»
# ---------------------
# Кронверк Синема Вэйпарк
# https://kinoteatr.ru/raspisanie-kinoteatrov/waypark/?day=tomorrow
# Москва, 71-й км МКАД, ТРЦ «Вэйпарк»
# ---------------------
# Синема Парк Глобал Сити на Южной
# https://kinoteatr.ru/raspisanie-kinoteatrov/global-city/?day=tomorrow
# Москва, ул. Днепропетровская, д.2, ТРК Глобал Сити, 3-й этаж
# ---------------------
# Формула Кино Европа
# https://kinoteatr.ru/raspisanie-kinoteatrov/evropa/?day=tomorrow
# Москва, пл. Киевского Вокзала, 2, ТРЦ «Европейский»
# ---------------------
# Синема Парк Зеленопарк
# https://kinoteatr.ru/raspisanie-kinoteatrov/zelenopark/?day=tomorrow
# Зеленоград, Ленинградское шоссе, 18-й км, ТЦ «Zеленопарк»
# ---------------------
# Синема Парк на Калужской
# https://kinoteatr.ru/raspisanie-kinoteatrov/kaluzhskij/?day=tomorrow
# Москва, ул. Профсоюзная, 61a, ТЦ Калужский, 3-й этаж
# ---------------------
# Формула Кино на Кутузовском
# https://kinoteatr.ru/raspisanie-kinoteatrov/kutuzovskiy/?day=tomorrow
# Москва, Кутузовский просп., 57, ТРЦ «Океания»
# ---------------------
# Формула Кино Ладога
# https://kinoteatr.ru/raspisanie-kinoteatrov/ladoga/?day=tomorrow
# Москва, Широкая, 12
# ---------------------
# Формула Кино Лефортово
# https://kinoteatr.ru/raspisanie-kinoteatrov/lefortovo/?day=tomorrow
# Москва, ш. Энтузиастов, 12, корп. 2, ТК «Город Лефортово»
# ---------------------
# Синема Парк Метрополис на Войковской
# https://kinoteatr.ru/raspisanie-kinoteatrov/metropolis/?day=tomorrow
# Москва, Ленинградское шоссе, 16A, стр 4 ТЦ «Метрополис», 3-й этаж
# ---------------------
# Формула Кино на Мичуринском
# https://kinoteatr.ru/raspisanie-kinoteatrov/michurinsky/?day=tomorrow
# Москва, Мичуринский просп., Олимпийская деревня, 3, корп. 1, ТРЦ «Фестиваль»
# ---------------------
# Формула Кино на Можайке
# https://kinoteatr.ru/raspisanie-kinoteatrov/mozhayka/?day=tomorrow
# Москва, 53-й км МКАД, напротив гипермаркета «Ашан Марфино»
# ---------------------
# Кронверк Синема Облака
# https://kinoteatr.ru/raspisanie-kinoteatrov/oblaka/?day=tomorrow
# Москва, Ореховый б-р, 22а, ТРК «Облака»
# ---------------------
# Формула Кино на Полежаевской
# https://kinoteatr.ru/raspisanie-kinoteatrov/polezhaevskiy/?day=tomorrow
# Москва, Хорошевское шоссе, д. 27, ТРЦ «Хорошо!»
# ---------------------
# Синема Парк Пятая Авеню на Октябрьском Поле
# https://kinoteatr.ru/raspisanie-kinoteatrov/5avenu/?day=tomorrow
# Москва, ул. Маршала Бирюзова, 32, ТРЦ «5 Авеню», 3-й этаж
# ---------------------
# Синема Парк Ривьера на Автозаводской
# https://kinoteatr.ru/raspisanie-kinoteatrov/rivera/?day=tomorrow
# Москва, ул. Автозаводская, 18, ТРЦ «Ривьера», 3-й этаж
# ---------------------
# Кронверк Синема Семеновский
# https://kinoteatr.ru/raspisanie-kinoteatrov/semenovsky/?day=tomorrow
# Москва, Семеновская пл., 1, ТРЦ «Семеновский»
# ---------------------
# КИНО ОККО Афимолл Сити
# https://kinoteatr.ru/raspisanie-kinoteatrov/city/?day=tomorrow
# Москва, Пресненская наб., 2, ТЦ «Афимолл-сити»
# ---------------------
# Синема ПАРК Теплый стан
# https://kinoteatr.ru/raspisanie-kinoteatrov/tepliy-stan/?day=tomorrow
# Москва, п. Сосенское, Калужское шоссе 21км (или 41км МКАД), «МЕГА Тёплый стан», 1-й этаж
# ---------------------
# Синема Парк Филион на Багратионовской
# https://kinoteatr.ru/raspisanie-kinoteatrov/filion/?day=tomorrow
# Москва, Багратионовский пр., 5, ТРЦ «Филион», 4-й этаж
# ---------------------
# Синема Парк МЕГА Химки
# https://kinoteatr.ru/raspisanie-kinoteatrov/mega-himki/?day=tomorrow
# Московская обл., г. Химки, мкр-н ИКЕА, корпус 2, «МЕГА Химки», 2-й этаж
# ---------------------
# Формула Кино ЦДМ
# https://kinoteatr.ru/raspisanie-kinoteatrov/cdm/?day=tomorrow
# Москва, Театральный пр., 5/1, Центральный детский магазин
# ---------------------
# Формула Кино Чертаново
# https://kinoteatr.ru/raspisanie-kinoteatrov/chertanovo/?day=tomorrow
# Москва, мкр. Северное Чертаново, 1а, стр. 2, ТРЦ «Авентура»
# ---------------------
# Кино Оkkо Щёлковский
# https://kinoteatr.ru/raspisanie-kinoteatrov/shchelkovsky/?day=tomorrow
# г. Москва, Щёлковское шоссе, 75
# ---------------------

# %%
for i2, cinema_t in enumerate(cinemastt):
    r = requests.get(cinema_t['href'])
    soap = BeautifulSoup(r.text, 'lxml')
    filmss = soap.findAll('div', class_='shedule_movie bordered gtm_movie')
    films_dict_tomorrow = []
    for film1 in filmss:
        films_dict_tomorrow.append({
        'name' : film1['data-gtm-list-item-filmname'],
        'href' : film1.find('a', class_='gtm-ec-list-item-movie')['href'],
        'format' : film1['data-gtm-format'],
        'genre' : film1['data-gtm-list-item-genre'],
        'table' : film1.findAll('span', class_='shedule_session_time')
        })
cinemastt[i2]['filmss'] = films_dict_tomorrow

# %%
cinemastt
