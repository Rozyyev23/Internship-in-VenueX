# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://kinoteatr.ru'

# %%
a = requests.get(f'{base_url}/raspisanie-kinoteatrov')

# %%
s = BeautifulSoup(a.text, 'lxml')

# %%
cinemas = []

# %%
for i in s.findAll('div', class_='col-md-12 cinema_card'):
    name = i.find('h3').text.strip()
    href = i.find('a')['href'].strip()
    address = i.findAll('span', class_= 'sub_title')[0].text.strip()
    cinemas.append({
        'name': name,
        'href': href,
        'address': address,
    })
    print(name, href, address, sep='\n', end='\n---------------------\n')
# Out:
# Синема Парк Мега Белая Дача
# https://kinoteatr.ru/raspisanie-kinoteatrov/belaya-dacha/
# Московская обл., Люберецкий р-н, г. Котельники, 1-й Покровский проезд, д. 1, (14-й км МКАД), «МЕГА Белая дача», 1-й этаж
# ---------------------
# Синема Парк Бутово Молл
# https://kinoteatr.ru/raspisanie-kinoteatrov/butovo-mall/
# Москва, пос. Воскресенское, Чечерский пр., 51, ТРЦ «Бутово-молл»
# ---------------------
# Кронверк Синема Вэйпарк
# https://kinoteatr.ru/raspisanie-kinoteatrov/waypark/
# Москва, 71-й км МКАД, ТРЦ «Вэйпарк»
# ---------------------
# Синема Парк Глобал Сити на Южной
# https://kinoteatr.ru/raspisanie-kinoteatrov/global-city/
# Москва, ул. Днепропетровская, д.2, ТРК Глобал Сити, 3-й этаж
# ---------------------
# Формула Кино Европа
# https://kinoteatr.ru/raspisanie-kinoteatrov/evropa/
# Москва, пл. Киевского Вокзала, 2, ТРЦ «Европейский»
# ---------------------
# Синема Парк Зеленопарк
# https://kinoteatr.ru/raspisanie-kinoteatrov/zelenopark/
# Зеленоград, Ленинградское шоссе, 18-й км, ТЦ «Zеленопарк»
# ---------------------
# Синема Парк на Калужской
# https://kinoteatr.ru/raspisanie-kinoteatrov/kaluzhskij/
# Москва, ул. Профсоюзная, 61a, ТЦ Калужский, 3-й этаж
# ---------------------
# Формула Кино на Кутузовском
# https://kinoteatr.ru/raspisanie-kinoteatrov/kutuzovskiy/
# Москва, Кутузовский просп., 57, ТРЦ «Океания»
# ---------------------
# Формула Кино Ладога
# https://kinoteatr.ru/raspisanie-kinoteatrov/ladoga/
# Москва, Широкая, 12
# ---------------------
# Формула Кино Лефортово
# https://kinoteatr.ru/raspisanie-kinoteatrov/lefortovo/
# Москва, ш. Энтузиастов, 12, корп. 2, ТК «Город Лефортово»
# ---------------------
# Синема Парк Метрополис на Войковской
# https://kinoteatr.ru/raspisanie-kinoteatrov/metropolis/
# Москва, Ленинградское шоссе, 16A, стр 4 ТЦ «Метрополис», 3-й этаж
# ---------------------
# Формула Кино на Мичуринском
# https://kinoteatr.ru/raspisanie-kinoteatrov/michurinsky/
# Москва, Мичуринский просп., Олимпийская деревня, 3, корп. 1, ТРЦ «Фестиваль»
# ---------------------
# Формула Кино на Можайке
# https://kinoteatr.ru/raspisanie-kinoteatrov/mozhayka/
# Москва, 53-й км МКАД, напротив гипермаркета «Ашан Марфино»
# ---------------------
# Кронверк Синема Облака
# https://kinoteatr.ru/raspisanie-kinoteatrov/oblaka/
# Москва, Ореховый б-р, 22а, ТРК «Облака»
# ---------------------
# Формула Кино на Полежаевской
# https://kinoteatr.ru/raspisanie-kinoteatrov/polezhaevskiy/
# Москва, Хорошевское шоссе, д. 27, ТРЦ «Хорошо!»
# ---------------------
# Синема Парк Пятая Авеню на Октябрьском Поле
# https://kinoteatr.ru/raspisanie-kinoteatrov/5avenu/
# Москва, ул. Маршала Бирюзова, 32, ТРЦ «5 Авеню», 3-й этаж
# ---------------------
# Синема Парк Ривьера на Автозаводской
# https://kinoteatr.ru/raspisanie-kinoteatrov/rivera/
# Москва, ул. Автозаводская, 18, ТРЦ «Ривьера», 3-й этаж
# ---------------------
# Кронверк Синема Семеновский
# https://kinoteatr.ru/raspisanie-kinoteatrov/semenovsky/
# Москва, Семеновская пл., 1, ТРЦ «Семеновский»
# ---------------------
# КИНО ОККО Афимолл Сити
# https://kinoteatr.ru/raspisanie-kinoteatrov/city/
# Москва, Пресненская наб., 2, ТЦ «Афимолл-сити»
# ---------------------
# Синема ПАРК Теплый стан
# https://kinoteatr.ru/raspisanie-kinoteatrov/tepliy-stan/
# Москва, п. Сосенское, Калужское шоссе 21км (или 41км МКАД), «МЕГА Тёплый стан», 1-й этаж
# ---------------------
# Синема Парк Филион на Багратионовской
# https://kinoteatr.ru/raspisanie-kinoteatrov/filion/
# Москва, Багратионовский пр., 5, ТРЦ «Филион», 4-й этаж
# ---------------------
# Синема Парк МЕГА Химки
# https://kinoteatr.ru/raspisanie-kinoteatrov/mega-himki/
# Московская обл., г. Химки, мкр-н ИКЕА, корпус 2, «МЕГА Химки», 2-й этаж
# ---------------------
# Формула Кино ЦДМ
# https://kinoteatr.ru/raspisanie-kinoteatrov/cdm/
# Москва, Театральный пр., 5/1, Центральный детский магазин
# ---------------------
# Формула Кино Чертаново
# https://kinoteatr.ru/raspisanie-kinoteatrov/chertanovo/
# Москва, мкр. Северное Чертаново, 1а, стр. 2, ТРЦ «Авентура»
# ---------------------
# Кино Оkkо Щёлковский
# https://kinoteatr.ru/raspisanie-kinoteatrov/shchelkovsky/
# г. Москва, Щёлковское шоссе, 75
# ---------------------

# %%
for ind, cinema in enumerate(cinemas):
    r = requests.get(cinema['href'])
    soap = BeautifulSoup(r.text, 'lxml')
    films = soap.findAll('div', class_='shedule_movie bordered gtm_movie')
    films_dict = []
    for film in films:
        films_dict.append({
            'name':film['data-gtm-list-item-filmname'],
            'href': film.find('a', class_='gtm-ec-list-item-movie')['href'],
            'format': film['data-gtm-format'],
            'genre': film['data-gtm-list-item-genre'],
            'raiting_sub': film.findAll('i', class_='raiting_sub')[0].text.strip(),
            'raspisanie': film.findAll('span', class_='shedule_session_time'),
            'price': film.findAll('span', class_='shedule_session_price')
        })
    cinemas[ind]['films'] = films_dict

# %%
cinemas
# Out:
# [{'name': 'Синема Парк Мега Белая Дача',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/belaya-dacha/',
#   'address': 'Московская обл., Люберецкий р-н, г. Котельники, 1-й Покровский проезд, д. 1, (14-й км МКАД), «МЕГА Белая дача», 1-й этаж',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Ведьмы',
#     'href': 'https://kinoteatr.ru/film/vedmy-2/?cinema_prio=24',
#     'format': '2d,4dx',
#     'genre': 'приключения,семейный,фэнтези',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Грань времени',
#     'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'ужасы,фантастика',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Довод',
#     'href': 'https://kinoteatr.ru/film/dovod/?cinema_prio=24',
#     'format': 'imax,2d,4dx',
#     'genre': 'боевик,триллер,фантастика',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Криминальные боссы',
#     'href': 'https://kinoteatr.ru/film/kriminalnye-bossy/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'криминальная комедия',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Страна грёз',
#     'href': 'https://kinoteatr.ru/film/strana-gryoz-2/?cinema_prio=24',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]}]},
#  {'name': 'Синема Парк Бутово Молл',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/butovo-mall/',
#   'address': 'Москва, пос. Воскресенское, Чечерский пр., 51, ТРЦ «Бутово-молл»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Линия горизонта',
#     'href': 'https://kinoteatr.ru/film/liniya-gorizonta-2/?cinema_prio=79',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Кронверк Синема Вэйпарк',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/waypark/',
#   'address': 'Москва, 71-й км МКАД, ТРЦ «Вэйпарк»',
#   'films': [{'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>,
#      <span class="shedule_session_time">                      00:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Пункт назначения. Аквапарк',
#     'href': 'https://kinoteatr.ru/film/punkt-naznacheniya-akvapark/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Не все дома',
#     'href': 'https://kinoteatr.ru/film/ne-vse-doma-2/?cinema_prio=43',
#     'format': '2d',
#     'genre': 'комедия',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Синема Парк Глобал Сити на Южной',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/global-city/',
#   'address': 'Москва, ул. Днепропетровская, д.2, ТРК Глобал Сити, 3-й этаж',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=7',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=7',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=7',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=7',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=7',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Формула Кино Европа',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/evropa/',
#   'address': 'Москва, пл. Киевского Вокзала, 2, ТРЦ «Европейский»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                850 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Смертельные иллюзии',
#     'href': 'https://kinoteatr.ru/film/smertelnye-illyuzii-2/?cinema_prio=54',
#     'format': '2d',
#     'genre': 'триллер,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      00:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]}]},
#  {'name': 'Синема Парк Зеленопарк',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/zelenopark/',
#   'address': 'Зеленоград, Ленинградское шоссе, 18-й км, ТЦ «Zеленопарк»',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=37',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=37',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=37',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Синема Парк на Калужской',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/kaluzhskij/',
#   'address': 'Москва, ул. Профсоюзная, 61a, ТЦ Калужский, 3-й этаж',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=1',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=1',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=1',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=1',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                150 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=1',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Страна грёз',
#     'href': 'https://kinoteatr.ru/film/strana-gryoz-2/?cinema_prio=1',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Формула Кино на Кутузовском',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/kutuzovskiy/',
#   'address': 'Москва, Кутузовский просп., 57, ТРЦ «Океания»',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=49',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=49',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=49',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=49',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=49',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Довод',
#     'href': 'https://kinoteatr.ru/film/dovod/?cinema_prio=49',
#     'format': 'imax,2d,4dx',
#     'genre': 'боевик,триллер,фантастика',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                450 р.                                        </span>]},
#    {'name': 'Страна грёз',
#     'href': 'https://kinoteatr.ru/film/strana-gryoz-2/?cinema_prio=49',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Формула Кино Ладога',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/ladoga/',
#   'address': 'Москва, Широкая, 12',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=51',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                170 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=51',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                170 р.                                        </span>]}]},
#  {'name': 'Формула Кино Лефортово',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/lefortovo/',
#   'address': 'Москва, ш. Энтузиастов, 12, корп. 2, ТК «Город Лефортово»',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=48',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      22:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=48',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=48',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=48',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=48',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Кольская сверхглубокая',
#     'href': 'https://kinoteatr.ru/film/kolskaya-sverhglubokaya/?cinema_prio=48',
#     'format': '2d,dolby',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]}]},
#  {'name': 'Синема Парк Метрополис на Войковской',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/metropolis/',
#   'address': 'Москва, Ленинградское шоссе, 16A, стр 4 ТЦ «Метрополис», 3-й этаж',
#   'films': [{'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:15
#
#                          </span>,
#      <span class="shedule_session_time">                      00:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:00
#
#                          </span>,
#      <span class="shedule_session_time">                      00:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:50
#
#                          </span>,
#      <span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>,
#      <span class="shedule_session_price">
#                                                900 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Довод',
#     'href': 'https://kinoteatr.ru/film/dovod/?cinema_prio=26',
#     'format': 'imax,2d,4dx',
#     'genre': 'боевик,триллер,фантастика',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Пункт назначения. Аквапарк',
#     'href': 'https://kinoteatr.ru/film/punkt-naznacheniya-akvapark/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Страна грёз',
#     'href': 'https://kinoteatr.ru/film/strana-gryoz-2/?cinema_prio=26',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Формула Кино на Мичуринском',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/michurinsky/',
#   'address': 'Москва, Мичуринский просп., Олимпийская деревня, 3, корп. 1, ТРЦ «Фестиваль»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Вечер шутов или серьёзно с приветом',
#     'href': 'https://kinoteatr.ru/film/vecher-shutov-ili-seryozno-s-privetom-2/?cinema_prio=50',
#     'format': '2d',
#     'genre': 'комедия,мелодрама',
#     'raiting_sub': '6+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Формула Кино на Можайке',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/mozhayka/',
#   'address': 'Москва, 53-й км МКАД, напротив гипермаркета «Ашан Марфино»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=57',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:15
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=57',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=57',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=57',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=57',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=57',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Кронверк Синема Облака',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/oblaka/',
#   'address': 'Москва, Ореховый б-р, 22а, ТРК «Облака»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=45',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=45',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=45',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=45',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Формула Кино на Полежаевской',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/polezhaevskiy/',
#   'address': 'Москва, Хорошевское шоссе, д. 27, ТРЦ «Хорошо!»',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Изгоняющий дьявола: Инсомния',
#     'href': 'https://kinoteatr.ru/film/izgonyayuschiy-dyavola-insomniya/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Смертельные иллюзии',
#     'href': 'https://kinoteatr.ru/film/smertelnye-illyuzii-2/?cinema_prio=56',
#     'format': '2d',
#     'genre': 'триллер,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      00:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
# ...
#    {'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:25
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Ведьмы',
#     'href': 'https://kinoteatr.ru/film/vedmy-2/?cinema_prio=14',
#     'format': '2d,4dx',
#     'genre': 'приключения,семейный,фэнтези',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                350 р.                                        </span>]},
#    {'name': 'Грань времени',
#     'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'ужасы,фантастика',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=14',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]}]},
#  {'name': 'Синема Парк МЕГА Химки',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/mega-himki/',
#   'address': 'Московская обл., г. Химки, мкр-н ИКЕА, корпус 2, «МЕГА Химки», 2-й этаж',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=22',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=22',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=22',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:00
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]},
#    {'name': 'Грань времени',
#     'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=22',
#     'format': '2d',
#     'genre': 'ужасы,фантастика',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Криминальные боссы',
#     'href': 'https://kinoteatr.ru/film/kriminalnye-bossy/?cinema_prio=22',
#     'format': '2d',
#     'genre': 'криминальная комедия',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Пункт назначения. Аквапарк',
#     'href': 'https://kinoteatr.ru/film/punkt-naznacheniya-akvapark/?cinema_prio=22',
#     'format': '2d',
#     'genre': 'хоррор',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]}]},
#  {'name': 'Формула Кино ЦДМ',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/cdm/',
#   'address': 'Москва, Театральный пр., 5/1, Центральный детский магазин',
#   'films': [{'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=52',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=52',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=52',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:05
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                340 р.                                        </span>]},
#    {'name': 'Афера по-голливудски',
#     'href': 'https://kinoteatr.ru/film/afera-po-gollivudski/?cinema_prio=52',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Дичь',
#     'href': 'https://kinoteatr.ru/film/dich/?cinema_prio=52',
#     'format': '2d',
#     'genre': 'комедия,триллер,ужасы',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                340 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=52',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                340 р.                                        </span>]}]},
#  {'name': 'Формула Кино Чертаново',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/chertanovo/',
#   'address': 'Москва, мкр. Северное Чертаново, 1а, стр. 2, ТРЦ «Авентура»',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:40
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Еще по одной',
#     'href': 'https://kinoteatr.ru/film/esche-po-odnoy-2/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'драма',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Искусственный интеллект',
#     'href': 'https://kinoteatr.ru/film/iskusstvennyy-intellekt-2/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'боевик,комедия',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:20
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:45
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                150 р.                                        </span>]},
#    {'name': 'Грань времени',
#     'href': 'https://kinoteatr.ru/film/gran-vremeni/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'ужасы,фантастика',
#     'raiting_sub': '18+',
#     'raspisanie': [<span class="shedule_session_time">                      00:35
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Линия горизонта',
#     'href': 'https://kinoteatr.ru/film/liniya-gorizonta-2/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      22:55
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Колдовство: Новый ритуал',
#     'href': 'https://kinoteatr.ru/film/koldovstvo-novyy-ritual/?cinema_prio=53',
#     'format': '2d',
#     'genre': 'мистический триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                150 р.                                        </span>]}]},
#  {'name': 'Кино Оkkо Щёлковский',
#   'href': 'https://kinoteatr.ru/raspisanie-kinoteatrov/shchelkovsky/',
#   'address': 'г. Москва, Щёлковское шоссе, 75',
#   'films': [{'name': 'Непосредственно Каха',
#     'href': 'https://kinoteatr.ru/film/neposredstvenno-kaha/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'комедия,приключения',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      23:30
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'На острие',
#     'href': 'https://kinoteatr.ru/film/na-ostrie-2/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'драма,экшн',
#     'raiting_sub': '12+',
#     'raspisanie': [<span class="shedule_session_time">                      23:50
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                200 р.                                        </span>]},
#    {'name': 'Взаперти',
#     'href': 'https://kinoteatr.ru/film/begi/?cinema_prio=89',
#     'format': '2d',
#     'genre': 'триллер',
#     'raiting_sub': '16+',
#     'raspisanie': [<span class="shedule_session_time">                      00:10
#
#                          </span>],
#     'price': [<span class="shedule_session_price">
#                                                250 р.                                        </span>]}]}]
